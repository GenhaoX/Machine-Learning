# %% [markdown]
# # 线性回归

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,mean_squared_error,r2_score
from sklearn.datasets import load_iris,load_diabetes

# %%
data=load_diabetes()
X=data['data']
y=data['target']
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42)

# %%
linear_regression=LinearRegression()
linear_regression.fit(X_train,y_train)
y_pred=linear_regression.predict(X_test)
print('MSE: %.2f'%mean_squared_error(y_test,y_pred))
print('R2: %.3f'%r2_score(y_test,y_pred))
print('score:%.3f'%linear_regression.score(X_test,y_test))#两个一样的
# y_pred
# Out:
# MSE: 2848.30
# R2: 0.485
# score:0.485

# %%
## 获得模型参数:回归系数和偏置
print("回归系数:",linear_regression.coef_)
print("偏置:",linear_regression.intercept_)
# Out:
# 回归系数: [  47.74657117 -241.99180361  531.96856896  381.56529922 -918.49020552
#   508.25147385  116.94040498  269.48508571  695.8062205    26.32343144]
# 偏置: 151.66516982689936

# %% [markdown]
# # 绘制散点图和拟合曲线图

# %%
plt.scatter(range(X_test.shape[0]), y_test, color='red',label='origin')
plt.plot(range(X_test.shape[0]), y_pred, color='blue', linewidth=3,label='predict')

plt.xticks(())
# plt.yticks(())
plt.legend(loc='upper center')
plt.title("LinearRegression Predict")
plt.show()
